# %% [markdown]
# #### Step 0: Install libraries.

# %%
# !pip3 install -q -U bitsandbytes
# !pip3 install -q -U peft
# !pip3 install -q -U trl
# !pip3 install -q -U accelerate
# !pip3 install -q -U datasets
# !pip3 install -q -U transformers
# !pip3 install -U tyro
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 kB 23.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro) (1.7.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from tyro) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro) (0.1.2)

# %% [markdown]
# #### Import libraries.

# %%
import os
import transformers
import torch
from datasets import load_dataset, Dataset, DatasetDict
from trl import SFTTrainer
from peft import LoraConfig, PeftModel
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig, GemmaTokenizer

# %%
# Login to Hugging Face account.
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# #### Step 1: Download Gemma-2b-it base model

# %%
model_id = "google/gemma-2b-it"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type = "nf4",
    bnb_4bit_compute_dtype = torch.bfloat16
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             quantization_config = bnb_config,
                                             device_map={"":0})
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
text = "Complete the dialogue: I'll make him an offer, he "
device = "cuda:0"
inputs = tokenizer(text, return_tensors = "pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=False))
# Out:
# <bos>Complete the dialogue: I'll make him an offer, he ___________________.
#
# The correct answer is "will accept".
#
# The dialogue could be continued as follows:
#
# I'll make him an offer, he **will accept** it.<eos>

# %% [markdown]
# #### Step 2: Configure LoRA settings for modules to be trained

# %%
os.environ["WANDB_DISABLE"] = "false"
os.environ['WANDB_MODE'] = 'disabled'

# %%
lora_config = LoraConfig(
    r = 8,
    target_modules = ["q_proj", "o_proj", "k_proj", "v_proj",
                      "gate_proj", "up_proj", "down_proj"],
    task_type = "CAUSAL_LM"
)

# %% [markdown]
# #### Step 3: Load the dataset

# %%
data1 = load_dataset("Seikaijyu/Beautiful-Chinese")
data1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 810284
#     })
# })

# %%
# for fast demo reduce the data num, remove this line when you want to train all data
data2 = data1['train'].select(range(100000))

# %%
data3 = data2.map(lambda samples: tokenizer(samples["question"], samples["answer"]), batched=False)

# %%
# This function won't do anything.
# Because the data had been tokenized
def formatting_func(example):
  text = f"Answer: {example['Answer'][0]}"
  return [text]

# %% [markdown]
# #### Step 4: Configure supervised fine-tuning parameters.

# %%
trainer = SFTTrainer(
    model = model,
    train_dataset = data3,
    args = transformers.TrainingArguments(
        per_device_train_batch_size = 4,
        gradient_accumulation_steps = 4,
        warmup_steps = 2,
        max_steps = 10000,  # just for fast demo, remove this line when you want to train all data
        learning_rate = 2e-4,
        fp16 = True,
        logging_steps = 10,
        output_dir = "outputs",
        optim = "paged_adamw_8bit"
    ),
    peft_config = lora_config,
    formatting_func = formatting_func

)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:309: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:463: UserWarning: You passed a dataset that is already processed (contains an `input_ids` field) together with a valid formatting function. Therefore `formatting_func` will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:403: UserWarning: You passed a processing_class with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `processing_class.padding_side = 'right'` to your code.
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# #### Step 5: Start model fine-tuning.

# %%
trainer.train()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
#     <div>
#
#       <progress value='31' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   31/10000 00:57 < 5:28:04, 0.51 it/s, Epoch 0.00/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>7.339100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.861900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>7.377400</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.516300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>5.992500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.501700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.952200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.789800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.991900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.711000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.892900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.305000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>4.266300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.918400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.540200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.464500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.345400</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.630100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.684100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.278600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.474900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.438600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.384600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.101700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>3.262800</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.152400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>3.022000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>3.348200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.232800</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# #### Step 6: Inference on the fine-tuned model.

# %%
text = "What is Hemoglobin?"

device = "cuda:0"

prompt = text + "\nAnswer:"

inputs = tokenizer(prompt, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=100, eos_token_id=tokenizer.eos_token_id)
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(answer)
# Out:
# What is Hemoglobin?
# Answer: Hemoglobin is a protein found in redbeds and vaguely in vertebrates. It is responsible for carrying oxygen from the lungs to the tissues and removing impra impra impractically from the tissues to the lungs.

# %%
text = "what is formula for perimeter of square? "

device = "cuda:0"

prompt = text + "\nAnswer:"

inputs = tokenizer(prompt, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=100, eos_token_id=tokenizer.eos_token_id)
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(answer)
# Out:
# what is formula for perimeter of square?
# Answer: The perimeter of a square is given by the formula:
#
# $$P = 4s$$
#
# where:
#
# * P is the perimeter in meters
# * s is the side length in meters

# %% [markdown]
# #### Step 7: Save the fine-tuned model.

# %%
fine_tuned_model = "fine_tuned_science_gemma2b-it_unmerged"
trainer.model.save_pretrained(fine_tuned_model)

# Push the model on Hugging Face.
base_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    low_cpu_mem_usage = True,
    return_dict = True,
    torch_dtype = torch.float16,
    device_map = {"": 0}
)

# Merge the fine-tuned model with LoRA adaption along with the base Gemma 2b-it model.
fine_tuned_merged_model = PeftModel.from_pretrained(base_model, fine_tuned_model)
fine_tuned_merged_model = fine_tuned_merged_model.merge_and_unload()

# Save the fine-tuned merged model.
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code = True)
fine_tuned_merged_model.save_pretrained("fine_tuned_science_gemma2b-it", safe_serialization = True)
tokenizer.save_pretrained("fine_tuned_science_gemma2b-it")
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# #### Step 8: Convert model to MediaPipe format for on-device deployment
# ***Note: You might need to restart the runtime before running the below cell.***

# %%
# !pip install mediapipe
# !pip install torch
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.23)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.23+cuda12.cudnn89)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from mediapipe) (2.2.1+cu121)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->mediapipe) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->mediapipe) (12.4.99)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->mediapipe) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->mediapipe) (1.3.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.11 sounddevice-0.4.6
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.99)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
from mediapipe.tasks.python.genai import converter

# %%
config = converter.ConversionConfig(
  input_ckpt='/content/fine_tuned_science_gemma2b-it/',
  ckpt_format="safetensors",
  model_type="GEMMA_2B",
  backend='gpu',
  output_dir='/content/intermediate/fine_tuned_science_gemma2b-it/',
  combine_file_only=False,
  vocab_model_file="/content/fine_tuned_science_gemma2b-it/",
  output_tflite_file=f'/content/fine_tuned_science_gemma2b-it/scigemma.bin',
)

converter.convert_checkpoint(config)

print("Model converted successfully.")
# Out:
# WARNING:jax._src.xla_bridge:CUDA backend failed to initialize: Found CUDA version 12010, but JAX was built against version 12020, which is newer. The copy of CUDA that is installed must be at least as new as the version against which JAX was built. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Model converted successfully.

# %% [markdown]
# #### Step 9: Push the fine-tuned model on Hugging Face.

# %%
from huggingface_hub import whoami
from pathlib import Path

# Output directory.
output_dir = "fine_tuned_science_gemma2b-it"
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{output_dir}"

# %%
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id


upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="Fine-tuned model pushed.",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# scigemma.bin:   0%|          | 0.00/2.52G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/NSTiwari/fine_tuned_science_gemma2b-it/commit/2abb637a1df5fd1b0cc6b21f840f4e08e668b1d8', commit_message='Fine-tuned model pushed.', commit_description='', oid='2abb637a1df5fd1b0cc6b21f840f4e08e668b1d8', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# #### (Optional) Convert model to MLC format for on-device deployment
# ***Note: You might need to restart the runtime.***

# %% [markdown]
# Install MLC LLM and TVM Unity Compiler

# %%
# !pip install --pre --force-reinstall mlc-ai-nightly-cu122 mlc-llm-nightly-cu122 -f https://mlc.ai/wheels
# Out:
# Looking in links: https://mlc.ai/wheels
# Collecting mlc-ai-nightly-cu122
#   Downloading https://github.com/mlc-ai/package/releases/download/v0.9.dev0/mlc_ai_nightly_cu122-0.15.dev223-cp310-cp310-manylinux_2_28_x86_64.whl (1018.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 GB 858.7 kB/s eta 0:00:00
# Collecting mlc-llm-nightly-cu122
#   Downloading https://github.com/mlc-ai/package/releases/download/v0.9.dev0/mlc_llm_nightly_cu122-0.1.dev1058-cp310-cp310-manylinux_2_28_x86_64.whl (145.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.6/145.6 MB 6.4 MB/s eta 0:00:00
# Collecting attrs (from mlc-ai-nightly-cu122)
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.1 MB/s eta 0:00:00
# Collecting cloudpickle (from mlc-ai-nightly-cu122)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting decorator (from mlc-ai-nightly-cu122)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting ml-dtypes (from mlc-ai-nightly-cu122)
#   Downloading ml_dtypes-0.4.0b1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.0 MB/s eta 0:00:00
# Collecting numpy (from mlc-ai-nightly-cu122)
#   Downloading numpy-2.0.0rc1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 63.5 MB/s eta 0:00:00
# Collecting psutil (from mlc-ai-nightly-cu122)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 37.0 MB/s eta 0:00:00
# Collecting scipy (from mlc-ai-nightly-cu122)
#   Downloading scipy-1.13.0rc1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.5/38.5 MB 14.0 MB/s eta 0:00:00
# Collecting tornado (from mlc-ai-nightly-cu122)
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 kB 40.4 MB/s eta 0:00:00
# Collecting typing-extensions (from mlc-ai-nightly-cu122)
#   Downloading typing_extensions-4.11.0rc1-py3-none-any.whl (34 kB)
# Collecting fastapi (from mlc-llm-nightly-cu122)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 14.5 MB/s eta 0:00:00
# Collecting uvicorn (from mlc-llm-nightly-cu122)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.6 MB/s eta 0:00:00
# Collecting shortuuid (from mlc-llm-nightly-cu122)
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Collecting torch (from mlc-llm-nightly-cu122)
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.0 MB/s eta 0:00:00
# Collecting safetensors (from mlc-llm-nightly-cu122)
#   Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.3 MB/s eta 0:00:00
# Collecting requests (from mlc-llm-nightly-cu122)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 9.2 MB/s eta 0:00:00
# Collecting tqdm (from mlc-llm-nightly-cu122)
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 11.6 MB/s eta 0:00:00
# Collecting tiktoken (from mlc-llm-nightly-cu122)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 95.4 MB/s eta 0:00:00
# Collecting prompt-toolkit (from mlc-llm-nightly-cu122)
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 34.2 MB/s eta 0:00:00
# Collecting openai (from mlc-llm-nightly-cu122)
#   Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 29.6 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 37.2 MB/s eta 0:00:00
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 9.6 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0 (from openai->mlc-llm-nightly-cu122)
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 12.5 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0 (from openai->mlc-llm-nightly-cu122)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai->mlc-llm-nightly-cu122)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.4 MB/s eta 0:00:00
# Collecting sniffio (from openai->mlc-llm-nightly-cu122)
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting wcwidth (from prompt-toolkit->mlc-llm-nightly-cu122)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting charset-normalizer<4,>=2 (from requests->mlc-llm-nightly-cu122)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 20.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->mlc-llm-nightly-cu122)
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 9.6 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->mlc-llm-nightly-cu122)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 16.5 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->mlc-llm-nightly-cu122)
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 23.5 MB/s eta 0:00:00
# Collecting regex>=2022.1.18 (from tiktoken->mlc-llm-nightly-cu122)
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 kB 58.7 MB/s eta 0:00:00
# Collecting filelock (from torch->mlc-llm-nightly-cu122)
#   Downloading filelock-3.13.3-py3-none-any.whl (11 kB)
# Collecting sympy (from torch->mlc-llm-nightly-cu122)
#   Downloading sympy-1.12.1a2-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 110.5 MB/s eta 0:00:00
# Collecting networkx (from torch->mlc-llm-nightly-cu122)
#   Downloading networkx-3.3rc0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.1 MB/s eta 0:00:00
# Collecting jinja2 (from torch->mlc-llm-nightly-cu122)
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 19.3 MB/s eta 0:00:00
# Collecting fsspec (from torch->mlc-llm-nightly-cu122)
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 23.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.2.0 (from torch->mlc-llm-nightly-cu122)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting click>=7.0 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 15.9 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.6 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2 (from anyio<5,>=3.5.0->openai->mlc-llm-nightly-cu122)
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai->mlc-llm-nightly-cu122)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.9 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->mlc-llm-nightly-cu122)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->mlc-llm-nightly-cu122)
#   Downloading pydantic_core-2.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.5 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->torch->mlc-llm-nightly-cu122)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath>=0.19 (from sympy->torch->mlc-llm-nightly-cu122)
#   Downloading mpmath-1.4.0a0-py3-none-any.whl (537 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 537.3/537.3 kB 37.7 MB/s eta 0:00:00
# Installing collected packages: wcwidth, urllib3, typing-extensions, tqdm, tornado, sniffio, shortuuid, safetensors, regex, psutil, prompt-toolkit, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mpmath, MarkupSafe, idna, h11, fsspec, filelock, exceptiongroup, distro, decorator, cloudpickle, click, charset-normalizer, certifi, attrs, annotated-types, uvicorn, triton, sympy, scipy, requests, pydantic-core, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ml-dtypes, jinja2, httpcore, anyio, tiktoken, starlette, pydantic, nvidia-cusolver-cu12, mlc-ai-nightly-cu122, httpx, torch, openai, fastapi, mlc-llm-nightly-cu122
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Uninstalling typing_extensions-4.10.0:
#       Successfully uninstalled typing_extensions-4.10.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.2
#     Uninstalling safetensors-0.4.2:
#       Successfully uninstalled safetensors-0.4.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.12.25
#     Uninstalling regex-2023.12.25:
#       Successfully uninstalled regex-2023.12.25
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.43
#     Uninstalling prompt-toolkit-3.0.43:
#       Successfully uninstalled prompt-toolkit-3.0.43
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.1.105
#     Uninstalling nvidia-nvtx-cu12-12.1.105:
#       Successfully uninstalled nvidia-nvtx-cu12-12.1.105
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.99
#     Uninstalling nvidia-nvjitlink-cu12-12.4.99:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.99
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.19.3
#     Uninstalling nvidia-nccl-cu12-2.19.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.19.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.2.106
#     Uninstalling nvidia-curand-cu12-10.3.2.106:
#       Successfully uninstalled nvidia-curand-cu12-10.3.2.106
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.0.2.54
#     Uninstalling nvidia-cufft-cu12-11.0.2.54:
#       Successfully uninstalled nvidia-cufft-cu12-11.0.2.54
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.1.105
#     Uninstalling nvidia-cuda-runtime-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.1.105
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.1.105
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.1.105
#     Uninstalling nvidia-cuda-cupti-cu12-12.1.105:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.1.105
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.1.3.1
#     Uninstalling nvidia-cublas-cu12-12.1.3.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.1.3.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.3
#     Uninstalling filelock-3.13.3:
#       Successfully uninstalled filelock-3.13.3
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.0
#     Uninstalling exceptiongroup-1.2.0:
#       Successfully uninstalled exceptiongroup-1.2.0
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.6.0
#     Uninstalling annotated-types-0.6.0:
#       Successfully uninstalled annotated-types-0.6.0
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.3
#     Uninstalling pydantic_core-2.16.3:
#       Successfully uninstalled pydantic_core-2.16.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.1.0.106
#     Uninstalling nvidia-cusparse-cu12-12.1.0.106:
#       Successfully uninstalled nvidia-cusparse-cu12-12.1.0.106
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.2.26
#     Uninstalling nvidia-cudnn-cu12-8.9.2.26:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.2.26
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.3
#     Uninstalling Jinja2-3.1.3:
#       Successfully uninstalled Jinja2-3.1.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.4
#     Uninstalling pydantic-2.6.4:
#       Successfully uninstalled pydantic-2.6.4
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.4.5.107
#     Uninstalling nvidia-cusolver-cu12-11.4.5.107:
#       Successfully uninstalled nvidia-cusolver-cu12-11.4.5.107
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.0.0rc1 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.0rc1 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.0.0rc1 which is incompatible.
# datasets 2.17.0 requires fsspec[http]<=2023.10.0,>=2023.1.0, but you have fsspec 2024.3.1 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.
# google-colab 1.0.0 requires tornado==6.3.3, but you have tornado 6.4 which is incompatible.
# ibis-framework 8.0.0 requires numpy<2,>=1, but you have numpy 2.0.0rc1 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.3.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.0rc1 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.0.0rc1 which is incompatible.
# shapely 2.0.3 requires numpy<2,>=1.14, but you have numpy 2.0.0rc1 which is incompatible.
# statsmodels 0.14.1 requires numpy<2,>=1.18, but you have numpy 2.0.0rc1 which is incompatible.
# tensorflow 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.4.0b1 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.0.0rc1 which is incompatible.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.6.0 anyio-4.3.0 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 cloudpickle-3.0.0 decorator-5.1.1 distro-1.9.0 exceptiongroup-1.2.0 fastapi-0.110.0 filelock-3.13.3 fsspec-2024.3.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.6 jinja2-3.1.3 ml-dtypes-0.4.0b1 mlc-ai-nightly-cu122-0.15.dev223 mlc-llm-nightly-cu122-0.1.dev1058 mpmath-1.4.0a0 networkx-3.3rc0 numpy-2.0.0rc1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 openai-1.14.3 prompt-toolkit-3.0.43 psutil-5.9.8 pydantic-2.6.4 pydantic-core-2.16.3 regex-2023.12.25 requests-2.31.0 safetensors-0.4.2 scipy-1.13.0rc1 shortuuid-1.0.13 sniffio-1.3.1 starlette-0.36.3 sympy-1.12.1a2 tiktoken-0.6.0 torch-2.2.2 tornado-6.4 tqdm-4.66.2 triton-2.2.0 typing-extensions-4.11.0rc1 urllib3-2.2.1 uvicorn-0.29.0 wcwidth-0.2.13

# %%
# !pip install numpy==1.23.5
# Out:
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 70.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0rc1
#     Uninstalling numpy-2.0.0rc1:
#       Successfully uninstalled numpy-2.0.0rc1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# datasets 2.17.0 requires fsspec[http]<=2023.10.0,>=2023.1.0, but you have fsspec 2024.3.1 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# tensorflow 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.4.0b1 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.
# Successfully installed numpy-1.23.5

# %%
import mlc_llm
import torch

# %%
# Login to Hugging Face account.
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Configure model name and quantization type.
FINE_TUNED_MODEL_NAME = "fine_tuned_science_gemma2b-it"
QUANTIZATION= "q4f16_1"

# %%
# !nvidia-smi

# Check if CUDA is available.
torch.cuda.is_available()
# Out:
# Sun Mar 31 12:19:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# #### Convert fine-tuned model weights.

# %% [markdown]
# *Note:* Go to **/usr/local/lib/python3.10/dist-packages/tvm/relax/frontend/nn/exporter.py**", and comment Line 139:
#
#  `assert rx.analysis.well_formed(mod)`

# %% [markdown]
# *Note:* Go to **/usr/local/lib/python3.10/dist-packages/mlc_llm/loader/huggingface_loader.py**", and add the following line before line 115:
#
#  `preshared_funcs = {}`

# %%
# !python -m mlc_llm convert_weight /content/$FINE_TUNED_MODEL_NAME/ --quantization $QUANTIZATION -o /content/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-MLC/
# Out:
# [2024-03-31 12:19:45] INFO auto_config.py:115: Found model configuration: /content/fine_tuned_science_gemma2b-it/config.json
# [2024-03-31 12:19:48] INFO auto_device.py:76: Found device: cuda:0
# [2024-03-31 12:19:50] INFO auto_device.py:85: Not found device: rocm:0
# [2024-03-31 12:19:53] INFO auto_device.py:85: Not found device: metal:0
# [2024-03-31 12:19:55] INFO auto_device.py:85: Not found device: vulkan:0
# [2024-03-31 12:19:58] INFO auto_device.py:85: Not found device: opencl:0
# [2024-03-31 12:19:58] INFO auto_device.py:33: Using device: cuda:0
# [2024-03-31 12:19:58] INFO auto_weight.py:70: Finding weights in: /content/fine_tuned_science_gemma2b-it
# [2024-03-31 12:19:58] INFO auto_weight.py:136: Not found Huggingface PyTorch
# [2024-03-31 12:19:58] INFO auto_weight.py:143: Found source weight format: huggingface-safetensor. Source configuration: /content/fine_tuned_science_gemma2b-it/model.safetensors.index.json
# [2024-03-31 12:19:58] INFO auto_weight.py:106: Using source weight configuration: /content/fine_tuned_science_gemma2b-it/model.safetensors.index.json. Use `--source` to override.
# [2024-03-31 12:19:58] INFO auto_weight.py:110: Using source weight format: huggingface-safetensor. Use `--source-format` to override.
# [2024-03-31 12:19:58] INFO auto_config.py:153: Found model type: gemma. Use `--model-type` to override.
# Weight conversion with arguments:
#   --config          /content/fine_tuned_science_gemma2b-it/config.json
#   --quantization    GroupQuantize(name='q4f16_1', kind='group-quant', group_size=32, quantize_dtype='int4', storage_dtype='uint32', model_dtype='float16', linear_weight_layout='NK', quantize_embedding=True, quantize_final_fc=True, num_elem_per_storage=8, num_storage_per_group=4, max_int_value=7)
#   --model-type      gemma
#   --device          cuda:0
#   --source          /content/fine_tuned_science_gemma2b-it/model.safetensors.index.json
#   --source-format   huggingface-safetensor
#   --output          /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC
# [2024-03-31 12:19:58] INFO gemma_model.py:55: context_window_size not found in config.json. Falling back to max_position_embeddings (8192)
# [2024-03-31 12:19:58] INFO gemma_model.py:70: prefill_chunk_size defaults to context_window_size (8192)
# Start storing to cache /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC
# [2024-03-31 12:19:59] INFO huggingface_loader.py:185: Loading HF parameters from: /content/fine_tuned_science_gemma2b-it/model-00001-of-00002.safetensors
# [2024-03-31 12:20:07] INFO group_quantization.py:234: Compiling quantize function for key: ((256000, 2048), float16, cuda, axis=1, output_transpose=False)
# [2024-03-31 12:20:10] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.embed_tokens.q_weight", shape: (256000, 256), dtype: uint32
# [2024-03-31 12:20:11] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.embed_tokens.q_scale", shape: (256000, 64), dtype: float16
# [2024-03-31 12:20:11] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.0.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:12] INFO group_quantization.py:234: Compiling quantize function for key: ((2048, 16384), float16, cuda, axis=1, output_transpose=False)
# [2024-03-31 12:20:12] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:12] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:13] INFO group_quantization.py:234: Compiling quantize function for key: ((32768, 2048), float16, cuda, axis=1, output_transpose=False)
# [2024-03-31 12:20:14] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:14] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:14] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.0.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:14] INFO group_quantization.py:234: Compiling quantize function for key: ((2560, 2048), float16, cuda, axis=1, output_transpose=False)
# [2024-03-31 12:20:15] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:15] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:15] INFO group_quantization.py:234: Compiling quantize function for key: ((2048, 2048), float16, cuda, axis=1, output_transpose=False)
# [2024-03-31 12:20:16] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:16] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.0.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:16] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.1.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:17] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:17] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:18] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.1.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:18] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.1.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:18] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.10.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:19] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:19] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.10.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.10.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.11.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:20] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:21] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:21] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:21] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.11.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:21] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:21] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:22] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:22] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.11.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:22] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.12.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:22] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:22] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:23] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.12.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:23] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.12.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:23] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.13.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:24] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:24] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.13.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.13.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.14.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:25] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:26] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:26] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:26] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.14.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:26] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:27] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:27] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:27] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.14.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:27] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.15.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:27] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:27] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:28] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:28] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:28] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.15.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.15.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:29] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.16.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:29] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:30] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.16.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:30] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.16.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:31] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:31] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:31] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:32] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:32] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:32] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:32] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.2.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:32] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:32] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:33] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.2.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:33] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.2.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:33] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.3.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:34] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:34] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.3.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.3.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.4.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:35] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:36] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:37] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.4.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.4.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:37] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.5.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:37] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:38] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:38] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:38] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.5.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:38] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:39] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:39] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:39] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.5.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:39] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.6.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:39] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:39] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:40] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:40] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:41] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.6.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.6.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:41] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.7.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:41] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:42] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.7.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:42] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.7.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:42] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.8.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:43] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:43] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:44] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.8.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:44] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.8.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:44] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.9.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:45] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:45] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.mlp.gate_up_proj.q_weight", shape: (32768, 256), dtype: uint32
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.mlp.gate_up_proj.q_scale", shape: (32768, 64), dtype: float16
# [2024-03-31 12:20:46] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.9.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.self_attn.qkv_proj.q_weight", shape: (2560, 256), dtype: uint32
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.self_attn.qkv_proj.q_scale", shape: (2560, 64), dtype: float16
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.self_attn.o_proj.q_weight", shape: (2048, 256), dtype: uint32
# [2024-03-31 12:20:46] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.9.self_attn.o_proj.q_scale", shape: (2048, 64), dtype: float16
# [2024-03-31 12:20:46] INFO huggingface_loader.py:197: Unloading HF weight file: /content/fine_tuned_science_gemma2b-it/model-00001-of-00002.safetensors
# [2024-03-31 12:20:46] INFO huggingface_loader.py:185: Loading HF parameters from: /content/fine_tuned_science_gemma2b-it/model-00002-of-00002.safetensors
# [2024-03-31 12:20:46] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.17.input_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:47] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.mlp.down_proj.q_weight", shape: (2048, 2048), dtype: uint32
# [2024-03-31 12:20:47] INFO huggingface_loader.py:167: [Quantized] Parameter: "model.layers.17.mlp.down_proj.q_scale", shape: (2048, 512), dtype: float16
# [2024-03-31 12:20:47] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.layers.17.post_attention_layernorm.weight", shape: (2048,), dtype: float16
# [2024-03-31 12:20:47] INFO huggingface_loader.py:175: [Not quantized] Parameter: "model.norm.weight", shape: (2048,), dtype: float16
# 100% 110/110 [00:47<00:00,  2.31it/s]
# [2024-03-31 12:20:47] INFO huggingface_loader.py:197: Unloading HF weight file: /content/fine_tuned_science_gemma2b-it/model-00002-of-00002.safetensors
# [2024-03-31 12:20:47] INFO stats.py:76: Time usage: HF loading: 1.857 sec; Pre-quantization mapping: 30.845 sec; Quantization: 6.093 sec
# [2024-03-31 12:20:47] INFO stats.py:90: RAM usage: Peak RAM: 4.606 GB. Total bytes loaded from disk: 4.668 GB
#
# All finished, 38 total shards committed, record saved to /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/ndarray-cache.json
# [2024-03-31 12:20:47] INFO convert_weight.py:156: Parameter size after quantization: 1.313 GB
# [2024-03-31 12:20:47] INFO convert_weight.py:161: Total parameters: 2,506,172,416
# [2024-03-31 12:20:47] INFO convert_weight.py:162: Bits per parameter: 4.500
# [2024-03-31 12:20:47] INFO convert_weight.py:167: Saved to directory: /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC

# %% [markdown]
# #### Generate token config files.

# %%
# !mlc_llm gen_config /content/$FINE_TUNED_MODEL_NAME/ --quantization $QUANTIZATION \
  --conv-template gemma_instruction --context-window-size 768 -o /content/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-MLC/
# Out:
# [2024-03-31 12:20:57] INFO auto_config.py:115: Found model configuration: /content/fine_tuned_science_gemma2b-it/config.json
# [2024-03-31 12:20:57] INFO auto_config.py:153: Found model type: gemma. Use `--model-type` to override.
# [2024-03-31 12:20:57] INFO gemma_model.py:55: context_window_size not found in config.json. Falling back to max_position_embeddings (8192)
# [2024-03-31 12:20:57] INFO gemma_model.py:70: prefill_chunk_size defaults to context_window_size (8192)
# [2024-03-31 12:20:57] INFO config.py:106: Overriding context_window_size from 8192 to 768
# [2024-03-31 12:20:57] INFO config.py:106: Overriding max_batch_size from 1 to 80
# [2024-03-31 12:20:57] INFO gemma_model.py:78: Overriding prefill_chunk_size from 8192 to 768 (context_window_size)
# [2024-03-31 12:20:57] INFO gen_config.py:133: [generation_config.json] Setting bos_token_id: 2
# [2024-03-31 12:20:57] INFO gen_config.py:133: [generation_config.json] Setting eos_token_id: 1
# [2024-03-31 12:20:57] INFO gen_config.py:133: [generation_config.json] Setting pad_token_id: 0
# [2024-03-31 12:20:57] INFO gen_config.py:145: Found tokenizer config: /content/fine_tuned_science_gemma2b-it/tokenizer.model. Copying to /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/tokenizer.model
# [2024-03-31 12:20:57] INFO gen_config.py:145: Found tokenizer config: /content/fine_tuned_science_gemma2b-it/tokenizer.json. Copying to /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/tokenizer.json
# [2024-03-31 12:20:57] INFO gen_config.py:147: Not found tokenizer config: /content/fine_tuned_science_gemma2b-it/vocab.json
# [2024-03-31 12:20:57] INFO gen_config.py:147: Not found tokenizer config: /content/fine_tuned_science_gemma2b-it/merges.txt
# [2024-03-31 12:20:57] INFO gen_config.py:147: Not found tokenizer config: /content/fine_tuned_science_gemma2b-it/added_tokens.json
# [2024-03-31 12:20:57] INFO gen_config.py:145: Found tokenizer config: /content/fine_tuned_science_gemma2b-it/tokenizer_config.json. Copying to /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/tokenizer_config.json
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting temperature: 0.7
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting presence_penalty: 0.0
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting frequency_penalty: 0.0
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting repetition_penalty: 1.0
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting top_p: 0.95
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting mean_gen_len: 128
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting max_gen_len: 512
# [2024-03-31 12:20:57] INFO gen_config.py:75: [System default] Setting shift_fill_factor: 0.3
# [2024-03-31 12:20:57] INFO gen_config.py:198: Dumping configuration file to: /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/mlc-chat-config.json

# %% [markdown]
# #### Compile the model to Android format.

# %%
# !mlc_llm compile /content/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-MLC/mlc-chat-config.json \
    --device android -o /content/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-MLC/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-android.tar
# Out:
# [2024-03-31 12:21:07] INFO auto_config.py:69: Found model configuration: /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/mlc-chat-config.json
# [2024-03-31 12:21:07] INFO auto_config.py:153: Found model type: gemma. Use `--model-type` to override.
# [2024-03-31 12:21:07] WARNING auto_target.py:311: --system-lib-prefix is automatically picked from the filename, gemma_q4f16_1_, this allows us to use the filename as the model_lib in android/iOS builds. Please avoid renaming the .tar file when uploading the prebuilt.
# Compiling with arguments:
#   --config          GemmaConfig(hidden_size=2048, hidden_act='gelu', intermediate_size=16384, attention_bias=False, num_attention_heads=8, num_key_value_heads=1, head_dim=256, num_hidden_layers=18, rms_norm_eps=1e-06, vocab_size=256000, position_embedding_base=10000.0, context_window_size=768, prefill_chunk_size=768, tensor_parallel_shards=1, max_batch_size=80, kwargs={})
#   --quantization    GroupQuantize(name='q4f16_1', kind='group-quant', group_size=32, quantize_dtype='int4', storage_dtype='uint32', model_dtype='float16', linear_weight_layout='NK', quantize_embedding=True, quantize_final_fc=True, num_elem_per_storage=8, num_storage_per_group=4, max_int_value=7)
#   --model-type      gemma
#   --target          {"thread_warp_size": 1, "host": {"kind": "llvm", "tag": "", "keys": ["arm_cpu", "cpu"], "mtriple": "aarch64-linux-android"}, "texture_spatial_limit": 16384, "max_threads_per_block": 256, "max_function_args": 128, "max_num_threads": 256, "kind": "opencl", "max_shared_memory_per_block": 16384, "tag": "", "keys": ["opencl", "gpu"]}
#   --opt             flashinfer=0;cublas_gemm=0;faster_transformer=0;cudagraph=0;cutlass=0;ipc_allreduce_strategy=NONE
#   --system-lib-prefix "gemma_q4f16_1_"
#   --output          /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/fine_tuned_science_gemma2b-it-q4f16_1-android.tar
#   --overrides       context_window_size=None;sliding_window_size=None;prefill_chunk_size=None;attention_sink_size=None;max_batch_size=None;tensor_parallel_shards=None
# [2024-03-31 12:21:07] INFO compile.py:137: Creating model from: GemmaConfig(hidden_size=2048, hidden_act='gelu', intermediate_size=16384, attention_bias=False, num_attention_heads=8, num_key_value_heads=1, head_dim=256, num_hidden_layers=18, rms_norm_eps=1e-06, vocab_size=256000, position_embedding_base=10000.0, context_window_size=768, prefill_chunk_size=768, tensor_parallel_shards=1, max_batch_size=80, kwargs={})
# [2024-03-31 12:21:07] INFO compile.py:156: Exporting the model to TVM Unity compiler
# [2024-03-31 12:21:08] INFO compile.py:162: Running optimizations using TVM Unity
# [2024-03-31 12:21:08] INFO compile.py:176: Registering metadata: {'model_type': 'gemma', 'quantization': 'q4f16_1', 'context_window_size': 768, 'sliding_window_size': -1, 'attention_sink_size': -1, 'prefill_chunk_size': 768, 'tensor_parallel_shards': 1, 'kv_cache_bytes': 0}
# [2024-03-31 12:21:09] INFO pipeline.py:50: Running TVM Relax graph-level optimizations
# [2024-03-31 12:21:22] INFO pipeline.py:50: Lowering to TVM TIR kernels
# [2024-03-31 12:21:24] INFO pipeline.py:50: Running TVM TIR-level optimizations
# [2024-03-31 12:21:29] INFO pipeline.py:50: Running TVM Dlight low-level optimizations
# [2024-03-31 12:21:31] INFO pipeline.py:50: Lowering to VM bytecode
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `alloc_embedding_tensor`: 3.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `batch_decode`: 10.31 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `batch_prefill`: 99.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `batch_verify`: 99.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `create_tir_paged_kv_cache`: 0.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `decode`: 0.13 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `embed`: 3.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `prefill`: 99.00 MB
# [2024-03-31 12:21:32] INFO estimate_memory_usage.py:55: [Memory usage] Function `softmax_with_temperature`: 0.00 MB
# [2024-03-31 12:21:32] INFO pipeline.py:50: Compiling external modules
# [2024-03-31 12:21:32] INFO pipeline.py:50: Compilation complete! Exporting to disk
# [2024-03-31 12:21:39] INFO model_metadata.py:96: Total memory usage: 1443.52 MB (Parameters: 1344.52 MB. KVCache: 0.00 MB. Temporary buffer: 99.00 MB)
# [2024-03-31 12:21:39] INFO model_metadata.py:105: To reduce memory usage, tweak `prefill_chunk_size`, `context_window_size` and `sliding_window_size`
# [2024-03-31 12:21:39] INFO compile.py:198: Generated: /content/fine_tuned_science_gemma2b-it-q4f16_1-MLC/fine_tuned_science_gemma2b-it-q4f16_1-android.tar

# %% [markdown]
# #### Push the quantized model to Hugging Face.

# %%
from huggingface_hub import whoami
from pathlib import Path

# Output directory.
output_dir = "fine_tuned_science_gemma2b-it-q4f16_1-MLC"
repo_name = "scigemma_fine_tuned_quantized_MLC"
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{repo_name}"
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id
print(output_dir)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="Fine-tuned quantized Gemma 2b-it model.",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# fine_tuned_science_gemma2b-it-q4f16_1-MLC
# fine_tuned_science_gemma2b-it-q4f16_1-android.tar:   0%|          | 0.00/325k [00:00<?, ?B/s]
# Upload 41 LFS files:   0%|          | 0/41 [00:00<?, ?it/s]
# params_shard_0.bin:   0%|          | 0.00/262M [00:00<?, ?B/s]
# params_shard_1.bin:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# params_shard_11.bin:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# params_shard_10.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_12.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_13.bin:   0%|          | 0.00/30.7M [00:00<?, ?B/s]
# params_shard_14.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_15.bin:   0%|          | 0.00/32.6M [00:00<?, ?B/s]
# params_shard_16.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_17.bin:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# params_shard_18.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_19.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_2.bin:   0%|          | 0.00/32.8M [00:00<?, ?B/s]
# params_shard_20.bin:   0%|          | 0.00/32.8M [00:00<?, ?B/s]
# params_shard_21.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_22.bin:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# params_shard_23.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_24.bin:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# params_shard_25.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_26.bin:   0%|          | 0.00/30.7M [00:00<?, ?B/s]
# params_shard_27.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_28.bin:   0%|          | 0.00/32.6M [00:00<?, ?B/s]
# params_shard_29.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_3.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_30.bin:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# params_shard_31.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_32.bin:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# params_shard_33.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_34.bin:   0%|          | 0.00/30.7M [00:00<?, ?B/s]
# params_shard_35.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_36.bin:   0%|          | 0.00/32.6M [00:00<?, ?B/s]
# params_shard_37.bin:   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# params_shard_4.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_5.bin:   0%|          | 0.00/30.5M [00:00<?, ?B/s]
# params_shard_6.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_7.bin:   0%|          | 0.00/32.6M [00:00<?, ?B/s]
# params_shard_8.bin:   0%|          | 0.00/33.6M [00:00<?, ?B/s]
# params_shard_9.bin:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/NSTiwari/scigemma_fine_tuned_quantized_MLC/commit/f6b97b9b3ede79b23f8f500f83294379ff3785cf', commit_message='Fine-tuned quantized Gemma 2b-it model.', commit_description='', oid='f6b97b9b3ede79b23f8f500f83294379ff3785cf', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# #### Step 10: Download the fine-tuned compiled model.

# %%
# !zip -r /content/gemma_2b_it_fine_tuned.zip /content/$FINE_TUNED_MODEL_NAME-$QUANTIZATION-MLC

# %%
from google.colab import files
files.download("/content/gemma_2b_it_fine_tuned.zip")

# %%
from huggingface_hub import whoami
from pathlib import Path

# Output directory.
output_dir = "scigemma_fine_tuned_v0"
repo_name = "scigemma_fine_tuned_v0"
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{repo_name}"

# %%
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id
print(output_dir)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="Fine-tuned quantized Gemma 2b-it model.",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# scigemma_fine_tuned_v0
# CommitInfo(commit_url='https://huggingface.co/NSTiwari/scigemma_fine_tuned_v0/commit/0f06e2fea34decd766317c0faa84806dba4ed6ed', commit_message='Fine-tuned quantized Gemma 2b-it model.', commit_description='', oid='0f06e2fea34decd766317c0faa84806dba4ed6ed', pr_url=None, pr_revision=None, pr_num=None)
